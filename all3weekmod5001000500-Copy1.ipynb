# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai import *
from fastai.tabular import *

# %%
train_df = pd.read_csv('train.csv')

# %%
train_df.head().T
# Out:
#                                 0           1           2           3  \
# id                     1379560.00  1466964.00  1346989.00  1338232.00
# week                         1.00        1.00        1.00        1.00
# center_id                   55.00       55.00       55.00       55.00
# meal_id                   1885.00     1993.00     2539.00     2139.00
# checkout_price             136.83      136.83      134.86      339.50
# base_price                 152.29      135.83      135.86      437.53
# emailer_for_promotion        0.00        0.00        0.00        0.00
# homepage_featured            0.00        0.00        0.00        0.00
# num_orders                 177.00      270.00      189.00       54.00
#
#                                4
# id                     1448490.0
# week                         1.0
# center_id                   55.0
# meal_id                   2631.0
# checkout_price             243.5
# base_price                 242.5
# emailer_for_promotion        0.0
# homepage_featured            0.0
# num_orders                  40.0

# %%
min(train_df['emailer_for_promotion']),max(train_df['emailer_for_promotion'])
# Out:
# (0, 1)

# %%
plt.scatter(range(0,456548),train_df['emailer_for_promotion'])

# %%
len(train_df)
# Out:
# 456548

# %%
test_df = pd.read_csv('test_QoiMO9B.csv')

# %%
test_df.head().T
# Out:
#                                 0           1           2           3  \
# id                     1028232.00  1127204.00  1212707.00  1082698.00
# week                       146.00      146.00      146.00      146.00
# center_id                   55.00       55.00       55.00       55.00
# meal_id                   1885.00     1993.00     2539.00     2631.00
# checkout_price             158.11      160.11      157.14      162.02
# base_price                 159.11      159.11      159.14      162.02
# emailer_for_promotion        0.00        0.00        0.00        0.00
# homepage_featured            0.00        0.00        0.00        0.00
#
#                                 4
# id                     1400926.00
# week                       146.00
# center_id                   55.00
# meal_id                   1248.00
# checkout_price             163.93
# base_price                 163.93
# emailer_for_promotion        0.00
# homepage_featured            0.00

# %%
len(test_df)
# Out:
# 32573

# %%
fci_df = pd.read_csv('fulfilment_center_info.csv')

# %%
fci_df.head().T
# Out:
#                   0       1       2       3       4
# center_id        11      13     124      66      94
# city_code       679     590     590     648     632
# region_code      56      56      56      34      34
# center_type  TYPE_A  TYPE_B  TYPE_C  TYPE_A  TYPE_C
# op_area         3.7     6.7       4     4.1     3.6

# %%
len(fci_df)
# Out:
# 77

# %%
plt.scatter(range(0,77),fci_df['op_area'])

# %%
mi_df= pd.read_csv('meal_info.csv')

# %%
mi_df.head().T
# Out:
#                   0          1          2          3          4
# meal_id        1885       1993       2539       1248       2631
# category  Beverages  Beverages  Beverages  Beverages  Beverages
# cuisine        Thai       Thai       Thai     Indian     Indian

# %%
len(mi_df)
# Out:
# 51

# %%
train_fci = train_df.merge(fci_df, how='left', left_on='center_id', right_on='center_id')
test_fci = test_df.merge(fci_df, how='left', left_on='center_id', right_on='center_id')

# %%
train_fci.head().T
# Out:
#                              0        1        2        3        4
# id                     1379560  1466964  1346989  1338232  1448490
# week                         1        1        1        1        1
# center_id                   55       55       55       55       55
# meal_id                   1885     1993     2539     2139     2631
# checkout_price          136.83   136.83   134.86    339.5    243.5
# base_price              152.29   135.83   135.86   437.53    242.5
# emailer_for_promotion        0        0        0        0        0
# homepage_featured            0        0        0        0        0
# num_orders                 177      270      189       54       40
# city_code                  647      647      647      647      647
# region_code                 56       56       56       56       56
# center_type             TYPE_C   TYPE_C   TYPE_C   TYPE_C   TYPE_C
# op_area                      2        2        2        2        2

# %%
test_fci.head().T
# Out:
#                              0        1        2        3        4
# id                     1028232  1127204  1212707  1082698  1400926
# week                       146      146      146      146      146
# center_id                   55       55       55       55       55
# meal_id                   1885     1993     2539     2631     1248
# checkout_price          158.11   160.11   157.14   162.02   163.93
# base_price              159.11   159.11   159.14   162.02   163.93
# emailer_for_promotion        0        0        0        0        0
# homepage_featured            0        0        0        0        0
# city_code                  647      647      647      647      647
# region_code                 56       56       56       56       56
# center_type             TYPE_C   TYPE_C   TYPE_C   TYPE_C   TYPE_C
# op_area                      2        2        2        2        2

# %%
len(train_fci),len(test_fci)
# Out:
# (456548, 32573)

# %%
train_fci_mi = train_fci.merge(mi_df, how='left', left_on='meal_id', right_on='meal_id')
test_fci_mi = test_fci.merge(mi_df, how='left', left_on='meal_id', right_on='meal_id')

# %%
train_fci_mi.head().T
# Out:
#                                0          1          2          3          4
# id                       1379560    1466964    1346989    1338232    1448490
# week                           1          1          1          1          1
# center_id                     55         55         55         55         55
# meal_id                     1885       1993       2539       2139       2631
# checkout_price            136.83     136.83     134.86      339.5      243.5
# base_price                152.29     135.83     135.86     437.53      242.5
# emailer_for_promotion          0          0          0          0          0
# homepage_featured              0          0          0          0          0
# num_orders                   177        270        189         54         40
# city_code                    647        647        647        647        647
# region_code                   56         56         56         56         56
# center_type               TYPE_C     TYPE_C     TYPE_C     TYPE_C     TYPE_C
# op_area                        2          2          2          2          2
# category               Beverages  Beverages  Beverages  Beverages  Beverages
# cuisine                     Thai       Thai       Thai     Indian     Indian

# %%
test_fci_mi.head().T
# Out:
#                                0          1          2          3          4
# id                       1028232    1127204    1212707    1082698    1400926
# week                         146        146        146        146        146
# center_id                     55         55         55         55         55
# meal_id                     1885       1993       2539       2631       1248
# checkout_price            158.11     160.11     157.14     162.02     163.93
# base_price                159.11     159.11     159.14     162.02     163.93
# emailer_for_promotion          0          0          0          0          0
# homepage_featured              0          0          0          0          0
# city_code                    647        647        647        647        647
# region_code                   56         56         56         56         56
# center_type               TYPE_C     TYPE_C     TYPE_C     TYPE_C     TYPE_C
# op_area                        2          2          2          2          2
# category               Beverages  Beverages  Beverages  Beverages  Beverages
# cuisine                     Thai       Thai       Thai     Indian     Indian

# %%
plt.scatter(range(0,456548),train_fci_mi['op_area'])

# %%
len(train_fci_mi),len(test_fci_mi)
# Out:
# (456548, 32573)

# %%
plt.plot(train_fci_mi['week'],train_fci_mi['num_orders'])

# %%
min(train_fci_mi['num_orders'])
# Out:
# 13

# %%
train_fci_mi.head().T
# Out:
#                                0          1          2          3          4
# id                       1379560    1466964    1346989    1338232    1448490
# week                           1          1          1          1          1
# center_id                     55         55         55         55         55
# meal_id                     1885       1993       2539       2139       2631
# checkout_price            136.83     136.83     134.86      339.5      243.5
# base_price                152.29     135.83     135.86     437.53      242.5
# emailer_for_promotion          0          0          0          0          0
# homepage_featured              0          0          0          0          0
# num_orders                   177        270        189         54         40
# city_code                    647        647        647        647        647
# region_code                   56         56         56         56         56
# center_type               TYPE_C     TYPE_C     TYPE_C     TYPE_C     TYPE_C
# op_area                        2          2          2          2          2
# category               Beverages  Beverages  Beverages  Beverages  Beverages
# cuisine                     Thai       Thai       Thai     Indian     Indian

# %%
test_fci_mi
# Out:
#             id  week  center_id  meal_id  checkout_price  base_price  \
# 0      1028232   146         55     1885          158.11      159.11
# 32553      TYPE_A      4.5      Sandwich      Italian
# 32554      TYPE_A      4.5      Sandwich      Italian
# 32555      TYPE_A      4.5      Sandwich      Italian
# 32556      TYPE_A      4.5       Biryani       Indian
# 32557      TYPE_A      4.5       Biryani       Indian
# 32558      TYPE_A      4.5         Pizza  Continental
# 32559      TYPE_A      4.5         Pizza  Continental
# 32560      TYPE_A      4.5         Pizza  Continental
# 32561      TYPE_A      4.5       Seafood  Continental
# 32562      TYPE_A      4.5       Seafood  Continental
# 32563      TYPE_A      4.5       Seafood  Continental
# 32564      TYPE_A      4.5  Other Snacks         Thai
# 32565      TYPE_A      4.5  Other Snacks         Thai
# 32566      TYPE_A      4.5  Other Snacks         Thai
# 32567      TYPE_A      4.5        Desert       Indian
# 32568      TYPE_A      4.5        Desert       Indian
# 32569      TYPE_A      4.5        Desert       Indian
# 32570      TYPE_A      4.5         Salad      Italian
# 32571      TYPE_A      4.5         Salad      Italian
# 32572      TYPE_A      4.5         Salad      Italian
#
# [32573 rows x 14 columns]

# %%
procs=[FillMissing, Categorify, Normalize]

# %%
train_fci_mi['week'] = train_fci_mi['week']%52
test_fci_mi['week'] = test_fci_mi['week']%52

# %%
cat_vars = ['week', 'city_code', 'region_code','op_area','meal_id','center_id', 'center_type', 'category', 'cuisine', 'emailer_for_promotion', 'homepage_featured']
cont_vars = ['checkout_price', 'base_price']
dep_var = ['num_orders']

# %%
df = train_fci_mi[cat_vars + cont_vars + dep_var].copy()

# %%
val_cut = range(int(.05*len(train_df)))

# %%
data = (TabularList.from_df(df, cat_names=cat_vars, cont_names=cont_vars, procs=procs)
                   .split_by_idx(val_cut)
                   .label_from_df(cols=dep_var, label_cls=FloatList, log=True)
                    .add_test(ItemList.from_df(test_fci_mi))
                   .databunch())

# %%
max_log_y = np.log(np.max(train_df['num_orders'])*1.2)
y_range = torch.tensor([0, max_log_y], device=defaults.device)

# %%
def rmsle(pred:FloatTensor, targ:FloatTensor)->Rank0Tensor:
    "Exp RMSE between `pred` and `targ`."
    assert pred.numel() == targ.numel(), "Expected same numbers of elements in pred & targ"
    if len(pred.shape)==2: pred=pred.squeeze(1)
    pct_var = torch.log((pred+1)/(targ+1))
    return torch.sqrt((pct_var**2).mean())*100

# %%
learn = tabular_learner(data, layers=[1200,800,400], ps=[.2,0.1,0.01], emb_drop=0.2, 
                        y_range=y_range, metrics=[rmsle,exp_rmspe],emb_szs={'week': 20, 'city_code':20, 'region_code': 15,'op_area': 11,'meal_id': 20,'center_id':30, 'center_type': 7, 'category': 5, 'cuisine':10, 'emailer_for_promotion':5, 'homepage_featured':5 })

# %%
learn.model
# Out:
# TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(53, 20)
#     (1): Embedding(52, 20)
#     (2): Embedding(9, 15)
#     (3): Embedding(31, 11)
#     (4): Embedding(52, 20)
#     (5): Embedding(78, 30)
#     (6): Embedding(4, 7)
#     (7): Embedding(15, 5)
#     (8): Embedding(5, 10)
#     (9): Embedding(3, 5)
#     (10): Embedding(3, 5)
#   )
#   (emb_drop): Dropout(p=0.2)
#   (bn_cont): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=150, out_features=1200, bias=True)
#     (1): ReLU(inplace)
#     (2): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.2)
#     (4): Linear(in_features=1200, out_features=800, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.1)
#     (8): Linear(in_features=800, out_features=400, bias=True)
#     (9): ReLU(inplace)
#     (10): BatchNorm1d(400, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): Dropout(p=0.01)
#     (12): Linear(in_features=400, out_features=1, bias=True)
#   )
# )

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, 3e-4, wd=0.2)
# Out:
# Total time: 10:09 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>rmsle</th>
#     <th>exp_rmspe</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.336842</th>
#     <th>0.340738</th>
#     <th>10.974031</th>
#     <th>0.931154</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.305180</th>
#     <th>0.346643</th>
#     <th>11.053611</th>
#     <th>0.898866</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.293174</th>
#     <th>0.335498</th>
#     <th>10.908768</th>
#     <th>0.900553</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.281464</th>
#     <th>0.332994</th>
#     <th>10.858547</th>
#     <th>0.846267</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.277045</th>
#     <th>0.326435</th>
#     <th>10.774133</th>
#     <th>0.838957</th>
#   </tr>
# </table>

# %%
learn.fit_one_cycle(3, 1e-4)
# Out:
# Total time: 05:43 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>rmsle</th>
#     <th>exp_rmspe</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.283560</th>
#     <th>0.327499</th>
#     <th>10.777346</th>
#     <th>0.842045</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.265030</th>
#     <th>0.324646</th>
#     <th>10.759886</th>
#     <th>0.867904</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.271820</th>
#     <th>0.326023</th>
#     <th>10.760495</th>
#     <th>0.828392</th>
#   </tr>
# </table>

# %%
learn.fit_one_cycle(2, 3e-4)
# Out:
# Total time: 03:51 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>rmsle</th>
#     <th>exp_rmspe</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.278855</th>
#     <th>0.326431</th>
#     <th>10.814734</th>
#     <th>0.883067</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.260543</th>
#     <th>0.328000</th>
#     <th>10.792423</th>
#     <th>0.857724</th>
#   </tr>
# </table>

# %%
preds, _ = learn.get_preds(ds_type=DatasetType.Test)
key_ids = test_df['id']
out = pd.DataFrame({'id': key_ids, 'num_orders': np.exp(preds.numpy()[:,0])})

# %%
out
# Out:
#             id   num_orders
# 0      1028232   428.241425
# 1      1127204   305.400757
# 2      1212707   178.986725
# 3      1082698    86.970749
# 4      1400926    80.611572
# 5      1284113   337.426025
# 6      1197966   325.237579
# 7      1132739   504.038391
# 8      1057981   239.064453
# 9      1095932   188.057861
# 10     1454421   269.800812
# 11     1149765   281.963867
# 12     1166964   394.817291
# 13     1010949   361.971954
# 14     1409575   247.251373
# 15     1181616   149.057419
# 16     1456020   416.648438
# 17     1264395   277.694092
# 18     1472931   276.006073
# 19     1412015    96.318260
# 20     1461229   117.322372
# 21     1014564   126.363220
# 22     1485914   246.696701
# 23     1345389   263.258606
# 24     1006833   327.817993
# 25     1174921   224.804199
# 26     1175393   150.103470
# 27     1152412   197.695206
# 28     1497398   137.734680
# 29     1363486    98.370865
# ...        ...          ...
# 32543  1234660  2028.489136
# 32544  1404408   339.266693
# 32545  1234776   281.590210
# 32546  1349215   166.663818
# 32547  1207249   132.992676
# 32548  1414921   361.986969
# 32549  1126947   341.671051
# 32550  1096124    59.824135
# 32551  1498639   138.291092
# 32552  1430032   203.729172
# 32553  1111480   233.075882
# 32554  1449841   428.073212
# 32555  1290329   361.670380
# 32556  1324280    62.738132
# 32557  1457838    99.850868
# 32558  1222394   365.761292
# 32559  1141545   297.388763
# 32560  1363040   255.624908
# 32561  1330159   213.428467
# 32562  1070377   175.204041
# 32563  1001148   151.481277
# 32564  1169203   205.533432
# 32565  1389523   180.469604
# 32566  1304998   279.593719
# 32567  1462767   120.712852
# 32568  1250239   248.779449
# 32569  1039516   182.133606
# 32570  1158107   298.556702
# 32571  1444235   387.668365
# 32572  1291286   215.353134
#
# [32573 rows x 2 columns]

# %%
learn.save('j1')

# %%
out.to_csv('j1.csv', index=False)
